# %%
import numpy as np
import pandas as pd

# %%
a = np.random.randn(4,6)

# %%
a
# Out:
# array([[-0.10199105, -0.60883933,  0.97158881, -0.75898936,  0.23658818,
#         -1.1694904 ],
#        [-0.33006386,  1.36414492, -1.35859131,  0.82705447, -0.08962231,
#          0.85300577],
#        [ 1.33124199, -0.72459425,  0.65096738,  1.65943948, -1.18617214,
#         -1.27781144],
#        [ 0.99098694, -1.59611133,  0.56172645, -1.46946189, -0.29530965,
#         -0.46527428]])

# %%
import matplotlib.

# %%
b = a**2

# %%
b
# Out:
# array([[0.01040217, 0.37068533, 0.94398481, 0.57606485, 0.05597397,
#         1.3677078 ],
#        [0.10894215, 1.86089137, 1.84577036, 0.6840191 , 0.00803216,
#         0.72761885],
#        [1.77220523, 0.52503682, 0.42375853, 2.75373937, 1.40700435,
#         1.63280208],
#        [0.98205511, 2.54757139, 0.31553661, 2.15931824, 0.08720779,
#         0.21648015]])

# %%
plt.plot(a,b)
plt.show()
